# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_layers = range(2, 13)

w2d_avgs_0 = [651.38873, 585, 1178, 1576, 788, 6.04, 432, 295, 117, 257, 866]
w2d_stds_0 = [909, 243, 1014, 1199, 524, 124.8, 184, 167, 13, 376, 301]

plt.errorbar(n_layers, w2d_avgs_0, w2d_stds_0)
plt.xlabel("Number of Hidden Layers")
plt.ylabel("Evaluation Average Returns")
plt.title("Average Returns on Walker2d Task vs. Number of Hidden Layers in MLP")
# Out:
# Text(0.5, 1.0, 'Evaluation Average Returns on Walker2d Task vs. Number of Hidden Layers in MLP')

# %%
def plot_dagger(task, avgs, stds, bc, expert):
    iterations = range(20)
    plt.errorbar(iterations, avgs, stds, label=f"DAgger")
    plt.plot(iterations, bc, label="Behavioral Cloning")
    plt.plot(iterations, expert, label="Expert")
    plt.xlabel("Number of Iterations")
    plt.ylabel("Average Returns")
    plt.title(f"Average Returns on {task} Task vs. Number of DAgger Iterations")
    plt.legend()

# %%
ant_avgs = [3876.6191, 4645.878, 4718.915, 4611.874, 4638.579, 4366.331, 4524.541, 4440.3403, 4477.11, 4701.083, 4661.8975, 4720.8906, 4660.6436, 4743.413, 4774.38, 4744.793, 4624.2227, 4745.19, 4724.857, 4723.3774]
ant_stds = [1213.651, 61.064438, 126.013466, 114.371796, 271.5982, 696.7043, 916.8939, 764.751, 549.4647, 105.66145, 56.315685, 98.85751, 114.72985, 69.31367, 64.39462, 101.430435, 77.50714, 119.81652, 80.405815, 119.11937]
ant_bc = 20 * [3876]
ant_expert = 20 * [4800]

w2d_avgs = [651.38873, 479.0213, 2283.4502, 4103.974, 2382.8218, 2514.066, 3994.8508, 4986.316, 4747.7554, 5383.468, 5337.5503, 5343.165, 5310.559, 5394.909, 3282.3123, 4901.262, 2775.4043, 4020.331, 4973.5293, 261.88977]
w2d_stds =  [909.57336, 327.81894, 1678.858, 1474.479, 1163.0692, 1904.1056, 2018.3368, 644.5629, 1119.9227, 33.974613, 23.911623, 19.64658, 27.8601, 27.383633, 2352.1272, 1415.7098, 2256.5085, 1782.0427, 1175.3125, 31.556814]
w2d_bc = 20 * [651]
w2d_expert = 20 * [5410]

# %%
def plot_dagger(task, avgs, stds, bc, expert):
    iterations = range(20)
    plt.errorbar(iterations, avgs, stds, label=f"DAgger")
    plt.plot(iterations, bc, label="Behavioral Cloning")
    plt.plot(iterations, expert, label="Expert")
    plt.xlabel("Number of Iterations")
    plt.ylabel("Average Returns")
    plt.title(f"Average Returns on {task} Task vs. Number of DAgger Iterations")
    plt.legend()

# %%
plot_dagger("Ant", ant_avgs, ant_stds, ant_bc, ant_expert)

# %%
plot_dagger("Walker2d", w2d_avgs, w2d_stds, w2d_bc, w2d_expert)
